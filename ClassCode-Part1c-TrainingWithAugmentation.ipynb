# %%
import numpy as np
from keras.layers import Dense, Convolution2D, MaxPooling2D, Flatten, Activation, Dropout
from keras.models import Sequential
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator

# %%
model = Sequential()

model.add(Convolution2D(32,3,3,input_shape=(150,150,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Convolution2D(32,3,3))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Convolution2D(32,3,3))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

# %%
model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

# %%
model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# convolution2d_14 (Convolution2D) (None, 148, 148, 32)  896         convolution2d_input_6[0][0]
# ____________________________________________________________________________________________________
# activation_19 (Activation)       (None, 148, 148, 32)  0           convolution2d_14[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_14 (MaxPooling2D)   (None, 74, 74, 32)    0           activation_19[0][0]
# ____________________________________________________________________________________________________
# convolution2d_15 (Convolution2D) (None, 72, 72, 32)    9248        maxpooling2d_14[0][0]
# ____________________________________________________________________________________________________
# activation_20 (Activation)       (None, 72, 72, 32)    0           convolution2d_15[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_15 (MaxPooling2D)   (None, 36, 36, 32)    0           activation_20[0][0]
# ____________________________________________________________________________________________________
# convolution2d_16 (Convolution2D) (None, 34, 34, 32)    9248        maxpooling2d_15[0][0]
# ____________________________________________________________________________________________________
# activation_21 (Activation)       (None, 34, 34, 32)    0           convolution2d_16[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_16 (MaxPooling2D)   (None, 17, 17, 32)    0           activation_21[0][0]
# ____________________________________________________________________________________________________
# flatten_6 (Flatten)              (None, 9248)          0           maxpooling2d_16[0][0]
# ____________________________________________________________________________________________________
# dense_7 (Dense)                  (None, 64)            591936      flatten_6[0][0]
# ____________________________________________________________________________________________________
# activation_22 (Activation)       (None, 64)            0           dense_7[0][0]
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)              (None, 64)            0           activation_22[0][0]
# ____________________________________________________________________________________________________
# dense_8 (Dense)                  (None, 1)             65          dropout_3[0][0]
# ____________________________________________________________________________________________________
# activation_23 (Activation)       (None, 1)             0           dense_8[0][0]
# ====================================================================================================
# Total params: 611,393
# Trainable params: 611,393
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
sgd = SGD(lr=0.001,momentum=0.9)
model.compile(loss='binary_crossentropy',optimizer=sgd,metrics=['accuracy'])

# %%
train_datgen = ImageDataGenerator(rescale=1./255,
                           horizontal_flip=True,
                           rotation_range=90,
                           vertical_flip=True,
                           shear_range=0.5)

# %%
train_generator = train_datgen.flow_from_directory(
    './training/',
    target_size=(150,150),
    batch_size=16,
    class_mode='binary'
)
# Out:
# Found 2000 images belonging to 2 classes.

# %%
test_datagen = ImageDataGenerator(
    rescale=1./255,
#     height_shift_range=0.2,
#     vertical_flip=True
)

# %%
test_generator = test_datagen.flow_from_directory(
    './validation/',
    class_mode='binary',
    target_size=(150,150),
    batch_size=16
)
# Out:
# Found 989 images belonging to 2 classes.

# %%
model.fit_generator(train_generator,validation_data=test_generator,
                   nb_epoch=10,samples_per_epoch=2000,nb_val_samples=989)
# Out:
# Epoch 1/10
# 2000/2000 [==============================] - 93s - loss: 0.6863 - acc: 0.5660 - val_loss: 0.6792 - val_acc: 0.6320
# Epoch 2/10
# 2000/2000 [==============================] - 93s - loss: 0.6851 - acc: 0.5735 - val_loss: 0.6768 - val_acc: 0.6572
# Epoch 3/10
# 1728/2000 [========================>.....] - ETA: 10s - loss: 0.6792 - acc: 0.5862
